# %% [markdown]
# # Setup

# %%
import sys
import os
import numpy as np
import pandas as pd
from numpy.typing import NDArray
from sklearn.model_selection import cross_val_score

RANDOM_SEED = 42

sys.path.append(os.path.abspath("."))
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Train + Fine Tune Decision Tree for Moons Dataset

# %%
from sklearn.datasets import make_moons

X_moons, y_moons = make_moons(n_samples=10_000, noise=0.4, random_state=RANDOM_SEED)

# %%
X_moons
# Out:
# array([[ 0.9402914 ,  0.12230559],
#        [ 0.12454026, -0.42477546],
#        [ 0.26198823,  0.50841438],
#        ...,
#        [-0.24177973,  0.20957199],
#        [ 0.90679645,  0.54958215],
#        [ 2.08837082, -0.05050728]])

# %%
y_moons
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_moons, y_moons, test_size=0.2, random_state=RANDOM_SEED)

# %%
from sklearn.tree import DecisionTreeClassifier

# for Decision Trees, no scaling is needed!
dt_classifier = DecisionTreeClassifier(random_state=RANDOM_SEED)

# %% [markdown]
# Which parameters are available?

# %%
pd.DataFrame(dt_classifier.get_params().keys())
# Out:
#                            0
# 0                  ccp_alpha
# 1               class_weight
# 2                  criterion
# 3                  max_depth
# 4               max_features
# 5             max_leaf_nodes
# 6      min_impurity_decrease
# 7           min_samples_leaf
# 8          min_samples_split
# 9   min_weight_fraction_leaf
# 10              random_state
# 11                  splitter

# %% [markdown]
# Find a good hyperparameter setup using `GridSearchCV`

# %%
from sklearn.model_selection import GridSearchCV


param_grid = [
    {
        'max_depth': range(1, 8 + 1),
        #'max_features': [1, 2],
        'max_leaf_nodes': range(2, 100 + 1),
        'min_samples_split': [2, 3, 4]
    }
]

grid_search = GridSearchCV(
    dt_classifier,
    param_grid,
    cv=5,
    #scoring="neg_root_mean_squared_error"
    verbose=2
)


grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2376 candidates, totalling 11880 fits
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=2, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=3, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=4, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=5, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=6, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=7, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=8, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=2; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=3; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=4; total time=   0.0s
# [CV] END .max_depth=1, max_leaf_nodes=9, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=10, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=11, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=12, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=13, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=14, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=15, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=16, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=17, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=18, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=19, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=20, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=21, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=22, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=23, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=24, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=25, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=26, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=27, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=28, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=29, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=30, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=31, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=32, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=33, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=34, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=35, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=36, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=37, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=38, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=39, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=40, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=41, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=41, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=41, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=41, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=41, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=1, max_leaf_nodes=41, min_samples_split=3; total time=   0.0s
# ...
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=88, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=89, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=90, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=91, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=92, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=93, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=94, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=95, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=96, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=97, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=98, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=99, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=2; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=3; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=4; total time=   0.0s
# [CV] END max_depth=8, max_leaf_nodes=100, min_samples_split=4; total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid=[{'max_depth': range(1, 9),
#                           'max_leaf_nodes': range(2, 101),
#                           'min_samples_split': [2, 3, 4]}],
#              verbose=2)

# %%
grid_search.best_score_
# Out:
# 0.85925

# %%
grid_search.best_params_
# Out:
# {'max_depth': 7, 'max_leaf_nodes': 23, 'min_samples_split': 2}

# %%
grid_search.best_estimator_

dt_best = grid_search.best_estimator_
dt_best
# Out:
# DecisionTreeClassifier(max_depth=7, max_leaf_nodes=23, random_state=42)

# %% [markdown]
# ### Accuracy?

# %%
cross_val_score(dt_best, X_train, y_train, cv=5, scoring="accuracy").mean()
# Out:
# 0.85925

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier()
dummy_clf.fit(X_train, y_train)

cross_val_score(dummy_clf, X_train, y_train, cv=5, scoring="accuracy").mean()
# Out:
# 0.501625

# %% [markdown]
# ### Confusion Matrix?

# %%
from sklearn.calibration import cross_val_predict
from sklearn.metrics import confusion_matrix

y_train_pred = cross_val_predict(dt_best, X_train, y_train, cv=3)
cm = confusion_matrix(y_train, y_train_pred)
cm
# Out:
# array([[3400,  587],
#        [ 577, 3436]])

# %% [markdown]
# ### Percision and Recall?

# %%
from sklearn.metrics import precision_score, recall_score

precision_score(y_train, y_train_pred)
# Out:
# 0.8540889883171763

# %%
recall_score(y_train, y_train_pred)
# Out:
# 0.8562172937951658

# %%
from sklearn.metrics import f1_score

f1_score(y_train, y_train_pred)
# Out:
# 0.8551518168242908

# %% [markdown]
# ### Check against Test Set

# %%
y_test_pred = dt_best.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_test_pred)
# Out:
# 0.8735

# %%
cm_test = confusion_matrix(y_test, y_test_pred)
cm_test
# Out:
# array([[875, 138],
#        [115, 872]])

# %%
precision_score(y_test, y_test_pred)
# Out:
# 0.8633663366336634

# %%
recall_score(y_test, y_test_pred)
# Out:
# 0.8834853090172239

# %%
f1_score(y_test, y_test_pred)
# Out:
# 0.8733099649474211

# %%
f1_score(y_train, y_train_pred) - f1_score(y_test, y_test_pred)
# Out:
# -0.018158148123130324

# %% [markdown]
# # Continuation

# %%
from sklearn.model_selection import ShuffleSplit

N_TREES = 1_000
N_INSTANCES = 100

mini_sets: list[tuple[NDArray[np.float64], NDArray[np.float64]]] = []

rs = ShuffleSplit(n_splits=N_TREES, test_size=len(X_train) - N_INSTANCES, random_state=RANDOM_SEED)

for i, (train_index, test_index) in enumerate(rs.split(X_train)):
    X_mini_train = X_train[train_index]
    y_mini_train = y_train[train_index]

    mini_sets.append((X_mini_train, y_mini_train))

# %%
from sklearn import clone

accuracy_scores: list[float] = []
forest: list[DecisionTreeClassifier] = []

for i, (X_mini_train, y_mini_train) in enumerate(mini_sets):
    estimator: DecisionTreeClassifier = clone(dt_best)
    estimator.fit(X_mini_train, y_mini_train)
    forest.append(estimator)

    y_test_pred_mini = estimator.predict(X_test)
    mini_accuracy_score = accuracy_score(y_test, y_test_pred_mini)
    accuracy_scores.append(mini_accuracy_score)

    print(f"Run #{i + 1}: accuracy = {mini_accuracy_score}")

np.mean(accuracy_scores)
# Out:
# Run #1: accuracy = 0.8005
# Run #2: accuracy = 0.836
# Run #3: accuracy = 0.8
# Run #4: accuracy = 0.8295
# Run #5: accuracy = 0.7935
# Run #6: accuracy = 0.8315
# Run #7: accuracy = 0.798
# Run #8: accuracy = 0.8015
# Run #9: accuracy = 0.7665
# Run #10: accuracy = 0.829
# Run #11: accuracy = 0.794
# Run #12: accuracy = 0.78
# Run #13: accuracy = 0.7895
# Run #14: accuracy = 0.808
# Run #15: accuracy = 0.804
# Run #16: accuracy = 0.846
# Run #17: accuracy = 0.818
# Run #18: accuracy = 0.811
# Run #19: accuracy = 0.8175
# Run #20: accuracy = 0.826
# Run #21: accuracy = 0.797
# Run #22: accuracy = 0.82
# Run #23: accuracy = 0.7855
# Run #24: accuracy = 0.819
# Run #25: accuracy = 0.818
# Run #26: accuracy = 0.7945
# Run #27: accuracy = 0.843
# Run #28: accuracy = 0.85
# Run #29: accuracy = 0.8155
# Run #30: accuracy = 0.811
# Run #31: accuracy = 0.7845
# Run #32: accuracy = 0.8355
# Run #33: accuracy = 0.815
# Run #34: accuracy = 0.77
# Run #35: accuracy = 0.7785
# Run #36: accuracy = 0.794
# Run #37: accuracy = 0.792
# Run #38: accuracy = 0.761
# Run #39: accuracy = 0.818
# Run #40: accuracy = 0.8375
# Run #41: accuracy = 0.7585
# Run #42: accuracy = 0.7355
# Run #43: accuracy = 0.797
# Run #44: accuracy = 0.7845
# Run #45: accuracy = 0.7895
# Run #46: accuracy = 0.7885
# Run #47: accuracy = 0.8035
# Run #48: accuracy = 0.7775
# Run #49: accuracy = 0.739
# Run #50: accuracy = 0.7975
# Run #51: accuracy = 0.8245
# Run #52: accuracy = 0.82
# Run #53: accuracy = 0.798
# Run #54: accuracy = 0.7935
# Run #55: accuracy = 0.7845
# Run #56: accuracy = 0.805
# Run #57: accuracy = 0.809
# Run #58: accuracy = 0.818
# Run #59: accuracy = 0.7755
# Run #60: accuracy = 0.754
# Run #61: accuracy = 0.7825
# Run #62: accuracy = 0.805
# Run #63: accuracy = 0.767
# Run #64: accuracy = 0.799
# Run #65: accuracy = 0.82
# Run #66: accuracy = 0.8115
# Run #67: accuracy = 0.795
# Run #68: accuracy = 0.784
# Run #69: accuracy = 0.838
# Run #70: accuracy = 0.765
# Run #71: accuracy = 0.8445
# Run #72: accuracy = 0.8015
# Run #73: accuracy = 0.8045
# Run #74: accuracy = 0.8205
# Run #75: accuracy = 0.796
# Run #76: accuracy = 0.7885
# Run #77: accuracy = 0.8285
# Run #78: accuracy = 0.79
# Run #79: accuracy = 0.829
# Run #80: accuracy = 0.767
# Run #81: accuracy = 0.792
# Run #82: accuracy = 0.7855
# Run #83: accuracy = 0.8455
# Run #84: accuracy = 0.826
# Run #85: accuracy = 0.73
# Run #86: accuracy = 0.7445
# Run #87: accuracy = 0.808
# Run #88: accuracy = 0.8105
# Run #89: accuracy = 0.823
# Run #90: accuracy = 0.7345
# Run #91: accuracy = 0.792
# Run #92: accuracy = 0.828
# Run #93: accuracy = 0.8005
# Run #94: accuracy = 0.792
# Run #95: accuracy = 0.7995
# Run #96: accuracy = 0.7735
# Run #97: accuracy = 0.8175
# Run #98: accuracy = 0.7985
# Run #99: accuracy = 0.8165
# Run #100: accuracy = 0.79
# Run #101: accuracy = 0.7845
# Run #102: accuracy = 0.799
# Run #103: accuracy = 0.811
# Run #104: accuracy = 0.816
# Run #105: accuracy = 0.838
# Run #106: accuracy = 0.796
# Run #107: accuracy = 0.796
# Run #108: accuracy = 0.8055
# Run #109: accuracy = 0.797
# Run #110: accuracy = 0.8235
# Run #111: accuracy = 0.8065
# Run #112: accuracy = 0.854
# Run #113: accuracy = 0.8
# Run #114: accuracy = 0.8265
# Run #115: accuracy = 0.804
# Run #116: accuracy = 0.7915
# Run #117: accuracy = 0.8125
# Run #118: accuracy = 0.791
# Run #119: accuracy = 0.7955
# Run #120: accuracy = 0.803
# Run #121: accuracy = 0.789
# Run #122: accuracy = 0.712
# Run #123: accuracy = 0.805
# Run #124: accuracy = 0.794
# Run #125: accuracy = 0.819
# Run #126: accuracy = 0.8345
# Run #127: accuracy = 0.844
# Run #128: accuracy = 0.8365
# Run #129: accuracy = 0.751
# Run #130: accuracy = 0.7935
# Run #131: accuracy = 0.768
# Run #132: accuracy = 0.7715
# Run #133: accuracy = 0.773
# Run #134: accuracy = 0.8055
# Run #135: accuracy = 0.794
# Run #136: accuracy = 0.807
# Run #137: accuracy = 0.782
# Run #138: accuracy = 0.7655
# Run #139: accuracy = 0.833
# Run #140: accuracy = 0.796
# Run #141: accuracy = 0.79
# Run #142: accuracy = 0.747
# Run #143: accuracy = 0.814
# Run #144: accuracy = 0.805
# Run #145: accuracy = 0.7795
# Run #146: accuracy = 0.828
# Run #147: accuracy = 0.823
# Run #148: accuracy = 0.8085
# Run #149: accuracy = 0.7975
# Run #150: accuracy = 0.818
# Run #151: accuracy = 0.779
# Run #152: accuracy = 0.787
# Run #153: accuracy = 0.8115
# Run #154: accuracy = 0.8015
# Run #155: accuracy = 0.81
# Run #156: accuracy = 0.7645
# Run #157: accuracy = 0.8195
# Run #158: accuracy = 0.8225
# Run #159: accuracy = 0.7695
# Run #160: accuracy = 0.824
# Run #161: accuracy = 0.8145
# Run #162: accuracy = 0.718
# Run #163: accuracy = 0.8095
# Run #164: accuracy = 0.798
# Run #165: accuracy = 0.7995
# Run #166: accuracy = 0.8195
# Run #167: accuracy = 0.7985
# Run #168: accuracy = 0.788
# Run #169: accuracy = 0.799
# Run #170: accuracy = 0.8335
# Run #171: accuracy = 0.7715
# Run #172: accuracy = 0.8435
# Run #173: accuracy = 0.805
# Run #174: accuracy = 0.815
# Run #175: accuracy = 0.7885
# Run #176: accuracy = 0.7655
# Run #177: accuracy = 0.81
# Run #178: accuracy = 0.8415
# Run #179: accuracy = 0.7935
# Run #180: accuracy = 0.776
# Run #181: accuracy = 0.767
# Run #182: accuracy = 0.8265
# Run #183: accuracy = 0.8175
# Run #184: accuracy = 0.803
# Run #185: accuracy = 0.827
# Run #186: accuracy = 0.834
# Run #187: accuracy = 0.806
# Run #188: accuracy = 0.7735
# Run #189: accuracy = 0.789
# Run #190: accuracy = 0.778
# Run #191: accuracy = 0.8145
# Run #192: accuracy = 0.792
# Run #193: accuracy = 0.779
# Run #194: accuracy = 0.8165
# Run #195: accuracy = 0.8375
# Run #196: accuracy = 0.83
# Run #197: accuracy = 0.8475
# Run #198: accuracy = 0.8095
# Run #199: accuracy = 0.7775
# Run #200: accuracy = 0.785
# Run #201: accuracy = 0.761
# Run #202: accuracy = 0.82
# Run #203: accuracy = 0.755
# Run #204: accuracy = 0.7455
# Run #205: accuracy = 0.813
# Run #206: accuracy = 0.825
# Run #207: accuracy = 0.801
# Run #208: accuracy = 0.792
# Run #209: accuracy = 0.7925
# Run #210: accuracy = 0.8075
# Run #211: accuracy = 0.7835
# Run #212: accuracy = 0.776
# Run #213: accuracy = 0.801
# Run #214: accuracy = 0.784
# Run #215: accuracy = 0.825
# Run #216: accuracy = 0.751
# Run #217: accuracy = 0.8
# Run #218: accuracy = 0.813
# Run #219: accuracy = 0.794
# Run #220: accuracy = 0.7745
# Run #221: accuracy = 0.826
# Run #222: accuracy = 0.808
# Run #223: accuracy = 0.822
# Run #224: accuracy = 0.819
# Run #225: accuracy = 0.8195
# Run #226: accuracy = 0.8365
# Run #227: accuracy = 0.8345
# Run #228: accuracy = 0.798
# Run #229: accuracy = 0.8285
# Run #230: accuracy = 0.788
# Run #231: accuracy = 0.7965
# Run #232: accuracy = 0.805
# Run #233: accuracy = 0.778
# Run #234: accuracy = 0.824
# Run #235: accuracy = 0.83
# Run #236: accuracy = 0.8295
# Run #237: accuracy = 0.825
# Run #238: accuracy = 0.824
# Run #239: accuracy = 0.7995
# Run #240: accuracy = 0.8235
# Run #241: accuracy = 0.7655
# Run #242: accuracy = 0.825
# Run #243: accuracy = 0.812
# Run #244: accuracy = 0.8305
# Run #245: accuracy = 0.7845
# Run #246: accuracy = 0.8245
# Run #247: accuracy = 0.8165
# Run #248: accuracy = 0.815
# Run #249: accuracy = 0.832
# Run #250: accuracy = 0.762
# Run #251: accuracy = 0.8295
# Run #252: accuracy = 0.837
# Run #253: accuracy = 0.791
# Run #254: accuracy = 0.836
# Run #255: accuracy = 0.7735
# Run #256: accuracy = 0.8255
# Run #257: accuracy = 0.8395
# Run #258: accuracy = 0.7895
# Run #259: accuracy = 0.784
# Run #260: accuracy = 0.803
# Run #261: accuracy = 0.7985
# Run #262: accuracy = 0.818
# Run #263: accuracy = 0.779
# Run #264: accuracy = 0.793
# Run #265: accuracy = 0.8205
# Run #266: accuracy = 0.826
# Run #267: accuracy = 0.786
# Run #268: accuracy = 0.8095
# Run #269: accuracy = 0.829
# Run #270: accuracy = 0.787
# Run #271: accuracy = 0.8535
# Run #272: accuracy = 0.8035
# Run #273: accuracy = 0.7615
# Run #274: accuracy = 0.8265
# Run #275: accuracy = 0.8315
# Run #276: accuracy = 0.8085
# Run #277: accuracy = 0.8185
# Run #278: accuracy = 0.813
# Run #279: accuracy = 0.856
# Run #280: accuracy = 0.8135
# Run #281: accuracy = 0.8155
# Run #282: accuracy = 0.8095
# Run #283: accuracy = 0.806
# Run #284: accuracy = 0.8075
# Run #285: accuracy = 0.771
# Run #286: accuracy = 0.8035
# Run #287: accuracy = 0.816
# Run #288: accuracy = 0.7995
# Run #289: accuracy = 0.7855
# Run #290: accuracy = 0.791
# Run #291: accuracy = 0.844
# Run #292: accuracy = 0.8415
# Run #293: accuracy = 0.7815
# Run #294: accuracy = 0.7805
# Run #295: accuracy = 0.8045
# Run #296: accuracy = 0.8145
# Run #297: accuracy = 0.7985
# Run #298: accuracy = 0.806
# Run #299: accuracy = 0.808
# Run #300: accuracy = 0.811
# Run #301: accuracy = 0.794
# Run #302: accuracy = 0.7895
# Run #303: accuracy = 0.8255
# Run #304: accuracy = 0.7595
# Run #305: accuracy = 0.829
# Run #306: accuracy = 0.801
# Run #307: accuracy = 0.7815
# Run #308: accuracy = 0.8285
# Run #309: accuracy = 0.7575
# Run #310: accuracy = 0.819
# Run #311: accuracy = 0.84
# Run #312: accuracy = 0.79
# Run #313: accuracy = 0.8135
# Run #314: accuracy = 0.772
# Run #315: accuracy = 0.842
# Run #316: accuracy = 0.833
# Run #317: accuracy = 0.787
# Run #318: accuracy = 0.7765
# Run #319: accuracy = 0.8055
# Run #320: accuracy = 0.819
# Run #321: accuracy = 0.785
# Run #322: accuracy = 0.8125
# Run #323: accuracy = 0.8255
# Run #324: accuracy = 0.7705
# Run #325: accuracy = 0.8165
# Run #326: accuracy = 0.772
# Run #327: accuracy = 0.829
# Run #328: accuracy = 0.765
# Run #329: accuracy = 0.827
# Run #330: accuracy = 0.8305
# Run #331: accuracy = 0.803
# Run #332: accuracy = 0.8245
# Run #333: accuracy = 0.7935
# Run #334: accuracy = 0.8205
# Run #335: accuracy = 0.833
# Run #336: accuracy = 0.798
# Run #337: accuracy = 0.787
# Run #338: accuracy = 0.7635
# Run #339: accuracy = 0.7465
# Run #340: accuracy = 0.7765
# Run #341: accuracy = 0.7715
# Run #342: accuracy = 0.802
# Run #343: accuracy = 0.8015
# Run #344: accuracy = 0.829
# Run #345: accuracy = 0.8055
# Run #346: accuracy = 0.834
# Run #347: accuracy = 0.7775
# Run #348: accuracy = 0.7955
# Run #349: accuracy = 0.798
# Run #350: accuracy = 0.818
# Run #351: accuracy = 0.828
# Run #352: accuracy = 0.7935
# Run #353: accuracy = 0.8115
# Run #354: accuracy = 0.8095
# Run #355: accuracy = 0.7995
# Run #356: accuracy = 0.8135
# Run #357: accuracy = 0.774
# Run #358: accuracy = 0.764
# Run #359: accuracy = 0.7865
# Run #360: accuracy = 0.811
# Run #361: accuracy = 0.796
# Run #362: accuracy = 0.802
# Run #363: accuracy = 0.7875
# Run #364: accuracy = 0.789
# Run #365: accuracy = 0.8245
# Run #366: accuracy = 0.7935
# Run #367: accuracy = 0.822
# Run #368: accuracy = 0.782
# Run #369: accuracy = 0.7795
# Run #370: accuracy = 0.798
# Run #371: accuracy = 0.842
# Run #372: accuracy = 0.8315
# Run #373: accuracy = 0.826
# Run #374: accuracy = 0.8175
# Run #375: accuracy = 0.7755
# Run #376: accuracy = 0.814
# Run #377: accuracy = 0.797
# Run #378: accuracy = 0.7955
# Run #379: accuracy = 0.831
# Run #380: accuracy = 0.8235
# Run #381: accuracy = 0.7955
# Run #382: accuracy = 0.7375
# Run #383: accuracy = 0.831
# Run #384: accuracy = 0.8505
# Run #385: accuracy = 0.857
# Run #386: accuracy = 0.819
# Run #387: accuracy = 0.828
# Run #388: accuracy = 0.811
# Run #389: accuracy = 0.789
# Run #390: accuracy = 0.774
# Run #391: accuracy = 0.827
# Run #392: accuracy = 0.794
# Run #393: accuracy = 0.832
# Run #394: accuracy = 0.7065
# Run #395: accuracy = 0.784
# Run #396: accuracy = 0.773
# Run #397: accuracy = 0.797
# Run #398: accuracy = 0.7955
# Run #399: accuracy = 0.819
# Run #400: accuracy = 0.7175
# Run #401: accuracy = 0.8405
# Run #402: accuracy = 0.8405
# Run #403: accuracy = 0.815
# Run #404: accuracy = 0.819
# Run #405: accuracy = 0.721
# Run #406: accuracy = 0.809
# Run #407: accuracy = 0.813
# Run #408: accuracy = 0.825
# Run #409: accuracy = 0.7795
# Run #410: accuracy = 0.832
# Run #411: accuracy = 0.7785
# Run #412: accuracy = 0.7835
# Run #413: accuracy = 0.7745
# Run #414: accuracy = 0.8115
# Run #415: accuracy = 0.804
# Run #416: accuracy = 0.8185
# Run #417: accuracy = 0.8045
# Run #418: accuracy = 0.7885
# Run #419: accuracy = 0.8325
# Run #420: accuracy = 0.8395
# Run #421: accuracy = 0.786
# Run #422: accuracy = 0.806
# Run #423: accuracy = 0.8135
# Run #424: accuracy = 0.7915
# Run #425: accuracy = 0.7745
# Run #426: accuracy = 0.755
# Run #427: accuracy = 0.802
# Run #428: accuracy = 0.8305
# Run #429: accuracy = 0.796
# Run #430: accuracy = 0.7855
# Run #431: accuracy = 0.827
# Run #432: accuracy = 0.7555
# Run #433: accuracy = 0.7895
# Run #434: accuracy = 0.7825
# Run #435: accuracy = 0.7455
# Run #436: accuracy = 0.8215
# Run #437: accuracy = 0.7835
# Run #438: accuracy = 0.7785
# Run #439: accuracy = 0.789
# Run #440: accuracy = 0.8285
# Run #441: accuracy = 0.8255
# Run #442: accuracy = 0.842
# Run #443: accuracy = 0.7735
# Run #444: accuracy = 0.81
# Run #445: accuracy = 0.831
# Run #446: accuracy = 0.84
# Run #447: accuracy = 0.8045
# Run #448: accuracy = 0.8195
# Run #449: accuracy = 0.788
# Run #450: accuracy = 0.792
# Run #451: accuracy = 0.809
# Run #452: accuracy = 0.819
# Run #453: accuracy = 0.8455
# Run #454: accuracy = 0.8345
# Run #455: accuracy = 0.7975
# Run #456: accuracy = 0.7625
# Run #457: accuracy = 0.7615
# Run #458: accuracy = 0.809
# Run #459: accuracy = 0.778
# Run #460: accuracy = 0.81
# Run #461: accuracy = 0.808
# Run #462: accuracy = 0.7985
# Run #463: accuracy = 0.677
# Run #464: accuracy = 0.841
# Run #465: accuracy = 0.8095
# Run #466: accuracy = 0.8015
# Run #467: accuracy = 0.8375
# Run #468: accuracy = 0.797
# Run #469: accuracy = 0.815
# Run #470: accuracy = 0.8295
# Run #471: accuracy = 0.813
# Run #472: accuracy = 0.783
# Run #473: accuracy = 0.7905
# Run #474: accuracy = 0.8285
# Run #475: accuracy = 0.804
# Run #476: accuracy = 0.7865
# Run #477: accuracy = 0.8255
# Run #478: accuracy = 0.814
# Run #479: accuracy = 0.7885
# Run #480: accuracy = 0.776
# Run #481: accuracy = 0.8205
# Run #482: accuracy = 0.798
# Run #483: accuracy = 0.827
# Run #484: accuracy = 0.804
# Run #485: accuracy = 0.812
# Run #486: accuracy = 0.815
# Run #487: accuracy = 0.787
# Run #488: accuracy = 0.796
# Run #489: accuracy = 0.8295
# Run #490: accuracy = 0.7755
# Run #491: accuracy = 0.794
# Run #492: accuracy = 0.764
# Run #493: accuracy = 0.713
# Run #494: accuracy = 0.848
# Run #495: accuracy = 0.809
# Run #496: accuracy = 0.8005
# Run #497: accuracy = 0.82
# Run #498: accuracy = 0.829
# Run #499: accuracy = 0.808
# Run #500: accuracy = 0.761
# Run #501: accuracy = 0.826
# Run #502: accuracy = 0.8315
# Run #503: accuracy = 0.812
# Run #504: accuracy = 0.8185
# Run #505: accuracy = 0.777
# Run #506: accuracy = 0.8265
# Run #507: accuracy = 0.8205
# Run #508: accuracy = 0.752
# Run #509: accuracy = 0.8075
# Run #510: accuracy = 0.777
# Run #511: accuracy = 0.827
# Run #512: accuracy = 0.8215
# Run #513: accuracy = 0.7815
# Run #514: accuracy = 0.8535
# Run #515: accuracy = 0.8
# Run #516: accuracy = 0.7915
# Run #517: accuracy = 0.8305
# Run #518: accuracy = 0.821
# Run #519: accuracy = 0.818
# Run #520: accuracy = 0.8185
# Run #521: accuracy = 0.835
# Run #522: accuracy = 0.835
# Run #523: accuracy = 0.829
# Run #524: accuracy = 0.762
# Run #525: accuracy = 0.8135
# Run #526: accuracy = 0.747
# Run #527: accuracy = 0.7855
# Run #528: accuracy = 0.817
# Run #529: accuracy = 0.778
# Run #530: accuracy = 0.82
# Run #531: accuracy = 0.808
# Run #532: accuracy = 0.7135
# Run #533: accuracy = 0.8105
# Run #534: accuracy = 0.817
# Run #535: accuracy = 0.8235
# Run #536: accuracy = 0.783
# Run #537: accuracy = 0.816
# Run #538: accuracy = 0.7865
# Run #539: accuracy = 0.7715
# Run #540: accuracy = 0.7935
# Run #541: accuracy = 0.77
# Run #542: accuracy = 0.786
# Run #543: accuracy = 0.798
# Run #544: accuracy = 0.8025
# Run #545: accuracy = 0.8385
# Run #546: accuracy = 0.8195
# Run #547: accuracy = 0.834
# Run #548: accuracy = 0.7565
# Run #549: accuracy = 0.8255
# Run #550: accuracy = 0.7975
# Run #551: accuracy = 0.7645
# Run #552: accuracy = 0.8145
# Run #553: accuracy = 0.756
# Run #554: accuracy = 0.7985
# Run #555: accuracy = 0.821
# Run #556: accuracy = 0.7985
# Run #557: accuracy = 0.844
# Run #558: accuracy = 0.792
# Run #559: accuracy = 0.816
# Run #560: accuracy = 0.7925
# Run #561: accuracy = 0.772
# Run #562: accuracy = 0.7935
# Run #563: accuracy = 0.821
# Run #564: accuracy = 0.773
# Run #565: accuracy = 0.764
# Run #566: accuracy = 0.8
# Run #567: accuracy = 0.79
# Run #568: accuracy = 0.8025
# Run #569: accuracy = 0.8105
# Run #570: accuracy = 0.8115
# Run #571: accuracy = 0.78
# Run #572: accuracy = 0.843
# Run #573: accuracy = 0.8375
# Run #574: accuracy = 0.8375
# Run #575: accuracy = 0.8235
# Run #576: accuracy = 0.79
# Run #577: accuracy = 0.808
# Run #578: accuracy = 0.8265
# Run #579: accuracy = 0.8195
# Run #580: accuracy = 0.821
# Run #581: accuracy = 0.859
# Run #582: accuracy = 0.799
# Run #583: accuracy = 0.8075
# Run #584: accuracy = 0.8265
# Run #585: accuracy = 0.844
# Run #586: accuracy = 0.7955
# Run #587: accuracy = 0.8385
# Run #588: accuracy = 0.78
# Run #589: accuracy = 0.7535
# Run #590: accuracy = 0.8285
# Run #591: accuracy = 0.815
# Run #592: accuracy = 0.8155
# Run #593: accuracy = 0.821
# Run #594: accuracy = 0.741
# Run #595: accuracy = 0.8135
# Run #596: accuracy = 0.8215
# Run #597: accuracy = 0.784
# Run #598: accuracy = 0.8005
# Run #599: accuracy = 0.805
# Run #600: accuracy = 0.831
# Run #601: accuracy = 0.783
# Run #602: accuracy = 0.816
# Run #603: accuracy = 0.778
# Run #604: accuracy = 0.806
# Run #605: accuracy = 0.7835
# Run #606: accuracy = 0.798
# Run #607: accuracy = 0.7745
# Run #608: accuracy = 0.8215
# Run #609: accuracy = 0.8095
# Run #610: accuracy = 0.8255
# Run #611: accuracy = 0.765
# Run #612: accuracy = 0.785
# Run #613: accuracy = 0.8265
# Run #614: accuracy = 0.8335
# Run #615: accuracy = 0.8215
# Run #616: accuracy = 0.833
# Run #617: accuracy = 0.8205
# Run #618: accuracy = 0.8195
# Run #619: accuracy = 0.8065
# Run #620: accuracy = 0.803
# Run #621: accuracy = 0.82
# Run #622: accuracy = 0.7675
# Run #623: accuracy = 0.798
# Run #624: accuracy = 0.8275
# Run #625: accuracy = 0.8
# Run #626: accuracy = 0.8325
# Run #627: accuracy = 0.8075
# Run #628: accuracy = 0.794
# Run #629: accuracy = 0.799
# Run #630: accuracy = 0.794
# Run #631: accuracy = 0.813
# Run #632: accuracy = 0.8105
# Run #633: accuracy = 0.821
# Run #634: accuracy = 0.797
# Run #635: accuracy = 0.782
# Run #636: accuracy = 0.7715
# Run #637: accuracy = 0.7875
# Run #638: accuracy = 0.764
# Run #639: accuracy = 0.788
# Run #640: accuracy = 0.8075
# Run #641: accuracy = 0.8115
# Run #642: accuracy = 0.7735
# Run #643: accuracy = 0.812
# Run #644: accuracy = 0.7935
# Run #645: accuracy = 0.849
# Run #646: accuracy = 0.821
# Run #647: accuracy = 0.8155
# Run #648: accuracy = 0.8365
# Run #649: accuracy = 0.848
# Run #650: accuracy = 0.773
# Run #651: accuracy = 0.7995
# Run #652: accuracy = 0.802
# Run #653: accuracy = 0.8405
# Run #654: accuracy = 0.7815
# Run #655: accuracy = 0.829
# Run #656: accuracy = 0.7525
# Run #657: accuracy = 0.8265
# Run #658: accuracy = 0.7955
# Run #659: accuracy = 0.768
# Run #660: accuracy = 0.772
# Run #661: accuracy = 0.7815
# Run #662: accuracy = 0.772
# Run #663: accuracy = 0.7835
# Run #664: accuracy = 0.8555
# Run #665: accuracy = 0.7985
# Run #666: accuracy = 0.7745
# Run #667: accuracy = 0.792
# Run #668: accuracy = 0.8305
# Run #669: accuracy = 0.8405
# Run #670: accuracy = 0.815
# Run #671: accuracy = 0.796
# Run #672: accuracy = 0.825
# Run #673: accuracy = 0.815
# Run #674: accuracy = 0.7825
# Run #675: accuracy = 0.82
# Run #676: accuracy = 0.734
# Run #677: accuracy = 0.83
# Run #678: accuracy = 0.77
# Run #679: accuracy = 0.8265
# Run #680: accuracy = 0.775
# Run #681: accuracy = 0.818
# Run #682: accuracy = 0.8395
# Run #683: accuracy = 0.7875
# Run #684: accuracy = 0.795
# Run #685: accuracy = 0.78
# Run #686: accuracy = 0.833
# Run #687: accuracy = 0.792
# Run #688: accuracy = 0.8325
# Run #689: accuracy = 0.7945
# Run #690: accuracy = 0.8405
# Run #691: accuracy = 0.749
# Run #692: accuracy = 0.838
# Run #693: accuracy = 0.7895
# Run #694: accuracy = 0.824
# Run #695: accuracy = 0.806
# Run #696: accuracy = 0.7745
# Run #697: accuracy = 0.764
# Run #698: accuracy = 0.8
# Run #699: accuracy = 0.8025
# Run #700: accuracy = 0.791
# Run #701: accuracy = 0.7865
# Run #702: accuracy = 0.816
# Run #703: accuracy = 0.798
# Run #704: accuracy = 0.821
# Run #705: accuracy = 0.8
# Run #706: accuracy = 0.8175
# Run #707: accuracy = 0.7925
# Run #708: accuracy = 0.787
# Run #709: accuracy = 0.7565
# Run #710: accuracy = 0.7645
# Run #711: accuracy = 0.7775
# Run #712: accuracy = 0.777
# Run #713: accuracy = 0.824
# Run #714: accuracy = 0.838
# Run #715: accuracy = 0.7575
# Run #716: accuracy = 0.7995
# Run #717: accuracy = 0.731
# Run #718: accuracy = 0.8225
# Run #719: accuracy = 0.832
# Run #720: accuracy = 0.817
# Run #721: accuracy = 0.736
# Run #722: accuracy = 0.8405
# Run #723: accuracy = 0.7715
# Run #724: accuracy = 0.808
# Run #725: accuracy = 0.832
# Run #726: accuracy = 0.8275
# Run #727: accuracy = 0.8025
# Run #728: accuracy = 0.8255
# Run #729: accuracy = 0.813
# Run #730: accuracy = 0.7795
# Run #731: accuracy = 0.7835
# Run #732: accuracy = 0.8135
# Run #733: accuracy = 0.8235
# Run #734: accuracy = 0.8065
# Run #735: accuracy = 0.823
# Run #736: accuracy = 0.7745
# Run #737: accuracy = 0.773
# Run #738: accuracy = 0.8485
# Run #739: accuracy = 0.803
# Run #740: accuracy = 0.8195
# Run #741: accuracy = 0.802
# Run #742: accuracy = 0.7255
# Run #743: accuracy = 0.808
# Run #744: accuracy = 0.8015
# Run #745: accuracy = 0.7775
# Run #746: accuracy = 0.8185
# Run #747: accuracy = 0.8185
# Run #748: accuracy = 0.8405
# Run #749: accuracy = 0.807
# Run #750: accuracy = 0.835
# Run #751: accuracy = 0.7475
# Run #752: accuracy = 0.8285
# Run #753: accuracy = 0.821
# Run #754: accuracy = 0.828
# Run #755: accuracy = 0.8235
# Run #756: accuracy = 0.761
# Run #757: accuracy = 0.8115
# Run #758: accuracy = 0.8255
# Run #759: accuracy = 0.827
# Run #760: accuracy = 0.835
# Run #761: accuracy = 0.7575
# Run #762: accuracy = 0.772
# Run #763: accuracy = 0.805
# Run #764: accuracy = 0.838
# Run #765: accuracy = 0.811
# Run #766: accuracy = 0.7425
# Run #767: accuracy = 0.8445
# Run #768: accuracy = 0.8235
# Run #769: accuracy = 0.832
# Run #770: accuracy = 0.818
# Run #771: accuracy = 0.783
# Run #772: accuracy = 0.8055
# Run #773: accuracy = 0.8125
# Run #774: accuracy = 0.7925
# Run #775: accuracy = 0.791
# Run #776: accuracy = 0.8035
# Run #777: accuracy = 0.7955
# Run #778: accuracy = 0.769
# Run #779: accuracy = 0.7775
# Run #780: accuracy = 0.7855
# Run #781: accuracy = 0.8165
# Run #782: accuracy = 0.8395
# Run #783: accuracy = 0.845
# Run #784: accuracy = 0.792
# Run #785: accuracy = 0.797
# Run #786: accuracy = 0.767
# Run #787: accuracy = 0.846
# Run #788: accuracy = 0.7725
# Run #789: accuracy = 0.8255
# Run #790: accuracy = 0.736
# Run #791: accuracy = 0.7935
# Run #792: accuracy = 0.833
# Run #793: accuracy = 0.796
# Run #794: accuracy = 0.7925
# Run #795: accuracy = 0.8205
# Run #796: accuracy = 0.817
# Run #797: accuracy = 0.699
# Run #798: accuracy = 0.7865
# Run #799: accuracy = 0.8225
# Run #800: accuracy = 0.7535
# Run #801: accuracy = 0.8365
# Run #802: accuracy = 0.8325
# Run #803: accuracy = 0.848
# Run #804: accuracy = 0.818
# Run #805: accuracy = 0.82
# Run #806: accuracy = 0.753
# Run #807: accuracy = 0.79
# Run #808: accuracy = 0.8205
# Run #809: accuracy = 0.8355
# Run #810: accuracy = 0.8135
# Run #811: accuracy = 0.8135
# Run #812: accuracy = 0.8445
# Run #813: accuracy = 0.801
# Run #814: accuracy = 0.8
# Run #815: accuracy = 0.8195
# Run #816: accuracy = 0.793
# Run #817: accuracy = 0.7815
# Run #818: accuracy = 0.766
# Run #819: accuracy = 0.834
# Run #820: accuracy = 0.7885
# Run #821: accuracy = 0.7935
# Run #822: accuracy = 0.8105
# Run #823: accuracy = 0.791
# Run #824: accuracy = 0.787
# Run #825: accuracy = 0.804
# Run #826: accuracy = 0.7795
# Run #827: accuracy = 0.842
# Run #828: accuracy = 0.8435
# Run #829: accuracy = 0.8105
# Run #830: accuracy = 0.7655
# Run #831: accuracy = 0.771
# Run #832: accuracy = 0.826
# Run #833: accuracy = 0.825
# Run #834: accuracy = 0.8385
# Run #835: accuracy = 0.8025
# Run #836: accuracy = 0.8305
# Run #837: accuracy = 0.7555
# Run #838: accuracy = 0.7575
# Run #839: accuracy = 0.757
# Run #840: accuracy = 0.8235
# Run #841: accuracy = 0.795
# Run #842: accuracy = 0.8125
# Run #843: accuracy = 0.8025
# Run #844: accuracy = 0.763
# Run #845: accuracy = 0.8395
# Run #846: accuracy = 0.799
# Run #847: accuracy = 0.736
# Run #848: accuracy = 0.7945
# Run #849: accuracy = 0.7895
# Run #850: accuracy = 0.791
# Run #851: accuracy = 0.845
# Run #852: accuracy = 0.819
# Run #853: accuracy = 0.7635
# Run #854: accuracy = 0.812
# Run #855: accuracy = 0.8125
# Run #856: accuracy = 0.782
# Run #857: accuracy = 0.8155
# Run #858: accuracy = 0.783
# Run #859: accuracy = 0.8065
# Run #860: accuracy = 0.7825
# Run #861: accuracy = 0.831
# Run #862: accuracy = 0.834
# Run #863: accuracy = 0.779
# Run #864: accuracy = 0.7865
# Run #865: accuracy = 0.8185
# Run #866: accuracy = 0.696
# Run #867: accuracy = 0.721
# Run #868: accuracy = 0.8225
# Run #869: accuracy = 0.7995
# Run #870: accuracy = 0.843
# Run #871: accuracy = 0.8
# Run #872: accuracy = 0.8075
# Run #873: accuracy = 0.809
# Run #874: accuracy = 0.7915
# Run #875: accuracy = 0.817
# Run #876: accuracy = 0.7915
# Run #877: accuracy = 0.78
# Run #878: accuracy = 0.807
# Run #879: accuracy = 0.775
# Run #880: accuracy = 0.775
# Run #881: accuracy = 0.7395
# Run #882: accuracy = 0.8195
# Run #883: accuracy = 0.779
# Run #884: accuracy = 0.731
# Run #885: accuracy = 0.8285
# Run #886: accuracy = 0.7775
# Run #887: accuracy = 0.8045
# Run #888: accuracy = 0.8125
# Run #889: accuracy = 0.7935
# Run #890: accuracy = 0.7765
# Run #891: accuracy = 0.814
# Run #892: accuracy = 0.7585
# Run #893: accuracy = 0.8295
# Run #894: accuracy = 0.766
# Run #895: accuracy = 0.769
# Run #896: accuracy = 0.823
# Run #897: accuracy = 0.813
# Run #898: accuracy = 0.827
# Run #899: accuracy = 0.7415
# Run #900: accuracy = 0.8265
# Run #901: accuracy = 0.8075
# Run #902: accuracy = 0.7575
# Run #903: accuracy = 0.818
# Run #904: accuracy = 0.7605
# Run #905: accuracy = 0.77
# Run #906: accuracy = 0.7645
# Run #907: accuracy = 0.811
# Run #908: accuracy = 0.8115
# Run #909: accuracy = 0.8085
# Run #910: accuracy = 0.746
# Run #911: accuracy = 0.815
# Run #912: accuracy = 0.7515
# Run #913: accuracy = 0.7865
# Run #914: accuracy = 0.763
# Run #915: accuracy = 0.785
# Run #916: accuracy = 0.782
# Run #917: accuracy = 0.819
# Run #918: accuracy = 0.83
# Run #919: accuracy = 0.816
# Run #920: accuracy = 0.798
# Run #921: accuracy = 0.792
# Run #922: accuracy = 0.7895
# Run #923: accuracy = 0.814
# Run #924: accuracy = 0.81
# Run #925: accuracy = 0.8
# Run #926: accuracy = 0.7895
# Run #927: accuracy = 0.8275
# Run #928: accuracy = 0.787
# Run #929: accuracy = 0.7515
# Run #930: accuracy = 0.8175
# Run #931: accuracy = 0.778
# Run #932: accuracy = 0.788
# Run #933: accuracy = 0.787
# Run #934: accuracy = 0.783
# Run #935: accuracy = 0.7875
# Run #936: accuracy = 0.8185
# Run #937: accuracy = 0.8155
# Run #938: accuracy = 0.8075
# Run #939: accuracy = 0.804
# Run #940: accuracy = 0.8425
# Run #941: accuracy = 0.806
# Run #942: accuracy = 0.806
# Run #943: accuracy = 0.7845
# Run #944: accuracy = 0.8085
# Run #945: accuracy = 0.8135
# Run #946: accuracy = 0.7805
# Run #947: accuracy = 0.809
# Run #948: accuracy = 0.777
# Run #949: accuracy = 0.8205
# Run #950: accuracy = 0.81
# Run #951: accuracy = 0.795
# Run #952: accuracy = 0.8135
# Run #953: accuracy = 0.7965
# Run #954: accuracy = 0.781
# Run #955: accuracy = 0.7765
# Run #956: accuracy = 0.841
# Run #957: accuracy = 0.7945
# Run #958: accuracy = 0.8535
# Run #959: accuracy = 0.7505
# Run #960: accuracy = 0.817
# Run #961: accuracy = 0.796
# Run #962: accuracy = 0.7605
# Run #963: accuracy = 0.7705
# Run #964: accuracy = 0.7765
# Run #965: accuracy = 0.795
# Run #966: accuracy = 0.792
# Run #967: accuracy = 0.829
# Run #968: accuracy = 0.8275
# Run #969: accuracy = 0.7875
# Run #970: accuracy = 0.7825
# Run #971: accuracy = 0.7585
# Run #972: accuracy = 0.818
# Run #973: accuracy = 0.8305
# Run #974: accuracy = 0.8245
# Run #975: accuracy = 0.8255
# Run #976: accuracy = 0.7945
# Run #977: accuracy = 0.802
# Run #978: accuracy = 0.7995
# Run #979: accuracy = 0.8015
# Run #980: accuracy = 0.7945
# Run #981: accuracy = 0.7905
# Run #982: accuracy = 0.8
# Run #983: accuracy = 0.8075
# Run #984: accuracy = 0.8135
# Run #985: accuracy = 0.816
# Run #986: accuracy = 0.8205
# Run #987: accuracy = 0.811
# Run #988: accuracy = 0.828
# Run #989: accuracy = 0.8395
# Run #990: accuracy = 0.803
# Run #991: accuracy = 0.787
# Run #992: accuracy = 0.7755
# Run #993: accuracy = 0.8245
# Run #994: accuracy = 0.7975
# Run #995: accuracy = 0.8
# Run #996: accuracy = 0.832
# Run #997: accuracy = 0.811
# Run #998: accuracy = 0.821
# Run #999: accuracy = 0.781
# Run #1000: accuracy = 0.8305
# 0.8017464999999999

# %%
len(X_test)
# Out:
# 2000

# %%
from scipy.stats import mode

def forest_result(X_test: NDArray[np.float64], forest: list[DecisionTreeClassifier]) -> NDArray[np.int32]:
    Y_pred = np.empty([N_TREES, len(X_test)], dtype=np.uint8)

    for tree_index, tree in enumerate(forest):
        Y_pred[tree_index] = tree.predict(X_test)

    y_pred_majority_votes, n_votes = mode(Y_pred, axis=0)

    return y_pred_majority_votes


y_pred_majority_votes = forest_result(X_test, forest)
y_pred_majority_votes
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test, y_pred_majority_votes)
# Out:
# 0.8735
